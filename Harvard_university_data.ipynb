# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/harvard_reviews.csv')

# %%
df.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 4  2023-10-02T17:40:42-04:00            Desktop       5  review
#
#    helpful_votes                                              title  \
# 0              0                 Best classes and good environment
# 1              0                                 Harvard University
# 2              0                                 Walk around campus
# 3              0                     Interesting Harvard University
# 4              0  Lovely university campus has many historic and...
#
#                                                 text
# 0  Good thanks for everything good work group 👍 h...
# 1  Harvard University was founded in 1636 and is ...
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['published_date'] = pd.to_datetime(df['published_date'])

# %% [markdown]
# #EDA

# %% [markdown]
# # which plateform has most of the published review ?

# %%
df['published_platform'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='published_platform'>

# %% [markdown]
# # Whats the number of rating has most ?

# %%
df['rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# # From which platform most of the ratings are published?

# %%
sns.displot(data=df , x='rating' , y='published_platform')

# %% [markdown]
# # How much people gave votes?

# %%
df['helpful_votes'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='helpful_votes'>

# %% [markdown]
# # Which title has most of the rating and from which plateform they were gave?

# %%
top_title = df['title'].value_counts().head(15).index.tolist()


filtered = df[df['title'].isin(top_title)]

sns.scatterplot(data=filtered , x='title' , y='rating' , hue='published_platform')
plt.xticks(rotation=90)
plt.show()

# %%
from wordcloud import WordCloud

# %% [markdown]
# # which words are repeated maximum time?

# %%
text_col = df["text"]

text = ' '.join(text_col)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df
# Out:
#                  published_date published_platform  rating    type  \
# 0     2023-12-28 08:02:14-05:00             Mobile       5  review
# 1     2023-12-12 00:38:26-05:00            Desktop       4  review
# 2     2023-12-10 08:21:35-05:00             Mobile       3  review
# 3     2023-11-07 21:20:21-05:00            Desktop       4  review
# 4     2023-10-02 17:40:42-04:00            Desktop       5  review
# ...                         ...                ...     ...     ...
# 3179  2010-10-29 05:47:57-04:00            Desktop       3  review
# 3180  2010-08-23 06:08:51-04:00            Desktop       3  review
# 3181  2010-08-23 00:06:41-04:00            Desktop       5  review
# 3182  2010-06-03 07:37:36-04:00            Desktop       5  review
# 3183  2009-09-27 16:39:18-04:00            Desktop       5  review
#
#       helpful_votes                                              title  \
# 0                 0                 Best classes and good environment
# ...
